# %% [markdown]
# # CHAPTER 10 Deep Learning for Time Series
#
# ## Building a Training Pipeline
#
# ### Inspecting Our Data Set

# %%
library("data.table")

# %%
elec = fread("electricity.txt")
head(elec, 5)
# Out:
#   V1 V2 V3  V4  V5  V6   V7 V8   V9  V10 ... V312 V313 V314  V315 V316 V317
# 1 14 69 234 415 215 1056 29  840 226 265 ... 676  372  80100 4719 5002 48
# 2 18 92 312 556 292 1363 29 1102 271 340 ... 805  452  95200 4643 6617 65
# 3 21 96 312 560 272 1240 29 1025 270 300 ... 817  430  96600 4285 6571 64
# 4 20 92 312 443 213  845 24  833 179 211 ... 801  291  94500 4222 6365 65
# 5 22 91 312 346 190  647 16  733 186 179 ... 807  279  91300 4116 6298 75
#   V318 V319 V320 V321
# 1 38   1558 182  2162
# 2 47   2177 253  2835
# 3 43   2193 218  2764
# 4 39   1315 195  2735
# 5 40   1378 191  2721

# %%
ncol(elec)
nrow(elec)
# Out:
# [1] 321
# [1] 26304

# %%
# Figure 10-2. 24 hours sampled from the data set for 3 different locations

elec[125:148, plot(V4,    type = 'l', col = 1, ylim = c(0, 1000), ylab="Electric Use")]
elec[125:148, lines(V14,  type = 'l', col = 2)]
elec[125:148, lines(V114, type = 'l', col = 3)]
# Out:
# NULL
# NULL
# NULL
# plot without title

# %%
# Figure 10-3. A full seven-day cycle of the sampled data for the same three locations

elec[1:168, plot(V4,    type = 'l', col = 1, ylim = c(0, 1000), ylab="Electric Use")]
elec[1:168, lines(V14,  type = 'l', col = 2)]
elec[1:168, lines(V114, type = 'l', col = 3)]
# Out:
# NULL
# NULL
# NULL
# plot without title

# %%
# Figure 10-4. A week-long sample of the same three sites’ differenced power time series

# Fix bugs: modify next 3 lines (2022/01/20)
# elec.diff[1:168, plot( V4, type = 'l', col = 1, ylim = c(-350, 350))]
# elec.diff[1:168, lines(V14, type = 'l', col = 2)]
# elec.diff[1:168, lines(V114, type = 'l', col = 3)]

plot(diff(elec[1:168,  V4]),   type = 'l', col = 1, ylim = c(-350, 350), ylab="Electric Use")
lines(diff(elec[1:168, V14]),  type = 'l', col = 2)
lines(diff(elec[1:168, V114]), type = 'l', col = 3)
# Out:
# plot without title
